# %%
from PIL import Image
import matplotlib.pyplot as plt
image=Image.open("website.jpg").convert('LA')
image.save('greyscale.png')
plt.imshow(image)

# %%
! pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.62-cp36-abi3-win_amd64.whl (35.4 MB)
# Requirement already satisfied: numpy>=1.17.3; python_version >= "3.8" in f:\anaconda\lib\site-packages (from opencv-python) (1.19.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.62

# %%
import cv2
img=cv2.imread('website.jpg')
ret,bw_img = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
plt.imshow(bw_img)

# %%
Y64 = img/4
plt.imshow(Y64)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
Y32 = img/8
plt.imshow(Y32)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
Y16 = img/16
plt.imshow(Y16)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
